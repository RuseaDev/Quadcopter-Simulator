# %%
import importlib
import quaternions
importlib.reload(quaternions)
from quaternions import Quaternion

# %%
import numpy as np

# %%
q1 = Quaternion.from_axis_angle(np.array([1, 0, 0]), 90)
v = np.array([1,0,0])
rotated_v_in_q = q1.rotate(v)

# %%
rotated_v_in_q.display()
# Out:
# w: 0.0, x: 1.0000000000000002, y: 0.0, z: 0.0

# %%
q2 = Quaternion.from_axis_angle(np.array([1,1,1]), 90)
q2 = q2.normalize()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 q2 = Quaternion.from_axis_angle(np.array([1,1,1]), 90)
# ----> 2 q2 = q2.normalize()
#
# File c:\Users\alexh\Coding\Drone_Simulation\quaternions.py:26, in Quaternion.normalize(self)
#      24 def normalize(self):
#      25     length = np.sqrt(self.w**2 + self.x**2 + self.y**2 + self.z**2)
# ---> 26     normalized_q = self.q/length
#      27     return normalized_q
#
# AttributeError: 'Quaternion' object has no attribute 'q'
